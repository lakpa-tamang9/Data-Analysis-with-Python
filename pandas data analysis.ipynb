# %%
import pandas as pd # pandas To pd I bring you to.
url ='https://vincentarelbundock.github.io/Rdatasets/csv/HistData/Guerry.csv'
original_df = pd.read_csv(url)
print(original_df.head())
print(original_df.tail())
# Out:
# C:\Users\Lakpa\anaconda3\envs\tf-gpu\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Lakpa\anaconda3\envs\tf-gpu\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\Lakpa\anaconda3\envs\tf-gpu\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)
#    Unnamed: 0  dept Region    Department  Crime_pers  Crime_prop  Literacy  \
# 0           1     1      E           Ain       28870       15890        37
# 1           2     2      N         Aisne       26226        5521        51
# 2           3     3      C        Allier       26747        7925        13
# 3           4     4      E  Basses-Alpes       12935        7289        46
# 4           5     5      E  Hautes-Alpes       17488        8174        69
#
#    Donations  Infants  Suicides  ... Crime_parents  Infanticide  \
# ...

# %%
original_df = pd.read_csv(url, index_col=0) # `index_col=0`Is the first column indexDesignated as
print(original_df.head())
# Out:
#    dept Region    Department  Crime_pers  Crime_prop  Literacy  Donations  \
# 1     1      E           Ain       28870       15890        37       5098
# 2     2      N         Aisne       26226        5521        51       8901
# 3     3      C        Allier       26747        7925        13      10973
# 4     4      E  Basses-Alpes       12935        7289        46       2733
# 5     5      E  Hautes-Alpes       17488        8174        69       6962
#
#    Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 1    33120     35039    2:Med  ...             71           60
# 2    14572     12831    2:Med  ...              4           82
# 3    17044    114121    2:Med  ...             46           42
# 4    23018     14238     1:Sm  ...             70           12
# 5    23076     16171     1:Sm  ...             22           23
#
#    Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# ...

# %%
print(original_df.shape[0], original_df.shape[1])
# Out:
# 86 23

# %%
original_df.shape
# Out:
# (86, 23)

# %%
original_df.describe()
# Out:
#              dept    Crime_pers    Crime_prop   Literacy     Donations  \
# count   86.000000     86.000000     86.000000  86.000000     86.000000
# mean    46.883721  19754.406977   7843.058140  39.255814   7075.546512
# std     30.426157   7504.703073   3051.352839  17.364051   5834.595216
# min      1.000000   2199.000000   1368.000000  12.000000   1246.000000
# 25%     24.250000  14156.250000   5933.000000  25.000000   3446.750000
# 50%     45.500000  18748.500000   7595.000000  38.000000   5020.000000
# 75%     66.750000  25937.500000   9182.250000  51.750000   9446.750000
# max    200.000000  37014.000000  20235.000000  74.000000  37015.000000
#
#             Infants       Suicides     Wealth   Commerce     Clergy  \
# count     86.000000      86.000000  86.000000  86.000000  86.000000
# mean   19049.906977   36522.604651  43.500000  42.802326  43.430233
# std     8820.233546   31312.532649  24.969982  25.028370  24.999549
# ...

# %%
original_df.tail()
# Out:
#     dept Region    Department  Crime_pers  Crime_prop  Literacy  Donations  \
# 82    86      W        Vienne       15010        4710        25       8922
# 83    87      C  Haute-Vienne       16256        6402        13      13817
# 84    88      E        Vosges       18835        9044        62       4040
# 85    89      C         Yonne       18006        6516        47       4276
# 86   200    NaN         Corse        2199        4589        49      37015
#
#     Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 82    35224     21851    2:Med  ...             20            1
# 83    19940     33497    2:Med  ...             68            6
# 84    14978     33029    2:Med  ...             58           34
# 85    16616     12789    2:Med  ...             32           22
# 86    24743     37016    2:Med  ...             81            2
#
#     Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# ...

# %%
original_df.head()
# Out:
#    dept Region    Department  Crime_pers  Crime_prop  Literacy  Donations  \
# 1     1      E           Ain       28870       15890        37       5098
# 2     2      N         Aisne       26226        5521        51       8901
# 3     3      C        Allier       26747        7925        13      10973
# 4     4      E  Basses-Alpes       12935        7289        46       2733
# 5     5      E  Hautes-Alpes       17488        8174        69       6962
#
#    Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 1    33120     35039    2:Med  ...             71           60
# 2    14572     12831    2:Med  ...              4           82
# 3    17044    114121    2:Med  ...             46           42
# 4    23018     14238     1:Sm  ...             70           12
# 5    23076     16171     1:Sm  ...             22           23
#
#    Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# ...

# %%
original_df.dropna(inplace = True)
original_df.tail()
# Out:
#     dept Region    Department  Crime_pers  Crime_prop  Literacy  Donations  \
# 81    85      W        Vendee       20827        7566        28      14035
# 82    86      W        Vienne       15010        4710        25       8922
# 83    87      C  Haute-Vienne       16256        6402        13      13817
# 84    88      E        Vosges       18835        9044        62       4040
# 85    89      C         Yonne       18006        6516        47       4276
#
#     Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 81    62486     67963     1:Sm  ...             50           44
# 82    35224     21851    2:Med  ...             20            1
# 83    19940     33497    2:Med  ...             68            6
# 84    14978     33029    2:Med  ...             58           34
# 85    16616     12789    2:Med  ...             32           22
#
#     Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# ...

# %%
df = original_df[['Crime_prop','Literacy','Wealth','Distance']] #By selecting only some variables df Save as
df.head()
# Out:
#    Crime_prop  Literacy  Wealth  Distance
# 1       15890        37      73   218.372
# 2        5521        51      22    65.945
# 3        7925        13      61   161.927
# 4        7289        46      76   351.399
# 5        8174        69      83   320.280
